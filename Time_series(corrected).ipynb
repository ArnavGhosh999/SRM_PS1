# %%
! pip install numpy pandas matplotlib scipy networkx torch scikit-learn pyod seaborn
# !mkdir -p Image
# Out:
# Requirement already satisfied: numpy in c:\users\arnav\desktop\ps1\venv\lib\site-packages (2.1.3)
# Requirement already satisfied: pandas in c:\users\arnav\desktop\ps1\venv\lib\site-packages (2.2.3)
# Requirement already satisfied: matplotlib in c:\users\arnav\desktop\ps1\venv\lib\site-packages (3.10.1)
# Requirement already satisfied: scipy in c:\users\arnav\desktop\ps1\venv\lib\site-packages (1.15.2)
# Requirement already satisfied: networkx in c:\users\arnav\desktop\ps1\venv\lib\site-packages (3.4.2)
# Requirement already satisfied: torch in c:\users\arnav\desktop\ps1\venv\lib\site-packages (2.7.0)
# Requirement already satisfied: scikit-learn in c:\users\arnav\desktop\ps1\venv\lib\site-packages (1.6.1)
# Requirement already satisfied: pyod in c:\users\arnav\desktop\ps1\venv\lib\site-packages (2.0.5)
# Requirement already satisfied: seaborn in c:\users\arnav\desktop\ps1\venv\lib\site-packages (0.13.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\arnav\desktop\ps1\venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\arnav\desktop\ps1\venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\arnav\desktop\ps1\venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\arnav\desktop\ps1\venv\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\arnav\desktop\ps1\venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\arnav\desktop\ps1\venv\lib\site-packages (from matplotlib) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\arnav\desktop\ps1\venv\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\arnav\desktop\ps1\venv\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\arnav\desktop\ps1\venv\lib\site-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\arnav\desktop\ps1\venv\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: filelock in c:\users\arnav\desktop\ps1\venv\lib\site-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\arnav\desktop\ps1\venv\lib\site-packages (from torch) (4.13.2)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\arnav\desktop\ps1\venv\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: jinja2 in c:\users\arnav\desktop\ps1\venv\lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in c:\users\arnav\desktop\ps1\venv\lib\site-packages (from torch) (2025.3.2)
# Requirement already satisfied: setuptools in c:\users\arnav\desktop\ps1\venv\lib\site-packages (from torch) (80.0.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\arnav\desktop\ps1\venv\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\arnav\desktop\ps1\venv\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: numba>=0.51 in c:\users\arnav\desktop\ps1\venv\lib\site-packages (from pyod) (0.61.2)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in c:\users\arnav\desktop\ps1\venv\lib\site-packages (from numba>=0.51->pyod) (0.44.0)
# Requirement already satisfied: six>=1.5 in c:\users\arnav\desktop\ps1\venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\arnav\desktop\ps1\venv\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\arnav\desktop\ps1\venv\lib\site-packages (from jinja2->torch) (3.0.2)
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import networkx as nx
from scipy import signal
import torch
import torch.nn as nn
import torch.nn.functional as F
from sklearn.preprocessing import StandardScaler
from pyod.models.iforest import IForest
import time
import seaborn as sns
import os
import warnings
import json
from matplotlib.ticker import MaxNLocator
from datetime import datetime

warnings.filterwarnings("ignore")
sns.set_style("whitegrid")
plt.rcParams.update({'font.size': 12})
os.makedirs("Images", exist_ok=True)
os.makedirs("Data", exist_ok=True)
current_time = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")

# %%
def safe_plot(func):
    def wrapper(*args, **kwargs):
        try:
            result = func(*args, **kwargs)
            plt.close('all')
            return result
        except Exception as e:
            print(f"Error in plotting function {func.__name__}: {e}")
            plt.close('all')
            return None
    return wrapper

dataset_path = "Dataset\merged_data_20Hz.csv"
df = pd.read_csv(dataset_path)

if 'timestamp' not in df.columns:
    df['sample_index'] = np.arange(len(df))

print(f"Dataset shape: {df.shape}")
print(f"Columns in dataset: {', '.join(df.columns)}")
# Out:
# Dataset shape: (394370, 14)
# Columns in dataset: Time, Site Name, Point Machine Name, Direction, A Current, A Voltage, B Current, B Voltage, Type of A, Type of B, Polling of A, Polling of B, source_dataset, sample_index
